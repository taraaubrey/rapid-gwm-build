# %%
# %% create a template modules (this would normally be done based on a template file)
import logging

from rapid_gwm_build import create_simulation
from rapid_gwm_build.parsers.config_parser import ConfigParser

# create directory structure
from pathlib import Path

# folder structure preprocessing/node_data
Path("preprocessing").mkdir(parents=True, exist_ok=True)
Path("preprocessing/node_data").mkdir(parents=True, exist_ok=True)

# %%
input_yaml = r"examples\pakipaki\pakipaki_v1.yaml"
sim = create_simulation(input_yaml)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 input_yaml = r"examples\pakipaki\pakipaki_v1.yaml"
# ----> 2 sim = create_simulation(input_yaml)
#
# File ~\e_Python\a_rbm\rapid-gwm-build\src\rapid_gwm_build\factory.py:9, in create_simulation(cfg_filepath)
#       8 def create_simulation(cfg_filepath: os.PathLike):
# ----> 9     parsed = ConfigParser.parse(cfg_filepath)
#      10     for sim_name, sim_cfg in parsed.items():
#      11         # set working directory
#      12         ref_dir = Path(sim_cfg['ws']) / 'ref_data'
#
# File ~\e_Python\a_rbm\rapid-gwm-build\src\rapid_gwm_build\parsers\config_parser.py:96, in ConfigParser.parse(cls, config_filepath, dvc)
#      93 @classmethod
#      94 def parse(cls, config_filepath, dvc=True):
#      95     """Parse the user config and return a normalized structure."""
# ---> 96     config = cls.load_yaml(config_filepath) # First, substitute variables (like ${data_dir})
#      97     config = cls.substitute_config(config)
#      98     all_sims = {}
#
# File ~\e_Python\a_rbm\rapid-gwm-build\src\rapid_gwm_build\parsers\config_parser.py:19, in ConfigParser.load_yaml(cls, filepath)
#      17 """Load a YAML file and return the parsed content."""
#      18 if not os.path.exists(filepath):
# ---> 19     raise FileNotFoundError(f"Config file not found: {filepath}")
#      21 with open(filepath, 'r') as file:
#      22     return yaml.safe_load(file)
#
# FileNotFoundError: Config file not found: examples\pakipaki\pakipaki_v1.yaml
