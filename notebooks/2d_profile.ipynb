# %%
import flopy as fp
import numpy as np

# %%
k = np.ones_like((10,100)) * 10
nlay = k.shape[0]
ncol = k.shape[1]
delr = k[:,0]

# %%
sim = fp.mf6.MFSimulation()
tdis = fp.mf6.ModflowTdis(simulation=sim)
ims = fp.mf6.ModflowIms(simulation=sim)
gwf = fp.mf6.ModflowGwf(simulation=sim)

npf = fp.mf6.ModflowGwfnpf(
    model=gwf,
    k=k)
dis = fp.mf6.ModflowGwfdis(
    model=gwf,
    nlay=10,
    nrow=1,
    ncol=100,
    delf=delr,
    delc=delc,
    top=top,
    btm=btm,
    idomain=idomain,
)
ic = fp.mf6.ModflowGwfic(
    model=gef,
    strt=strt,
)
wel = fp.m6.ModflowGwfwel(
    model=gwf,
    stress_period_data=wel,
)
riv=fp.mf6.ModflowGwfriv(
    model=gwf,
    stress_period_data=riv,
)
